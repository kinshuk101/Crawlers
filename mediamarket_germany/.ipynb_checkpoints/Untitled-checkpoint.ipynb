# %%
import pandas as pd
import psycopg2
import numpy as np



from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support.ui import WebDriverWait
import selenium.webdriver.support.expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service



from tqdm import tqdm
tqdm.pandas()
import time



from bs4 import BeautifulSoup
import re

import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

# %%
s = Service("../chromedriver_win32/chromedriver.exe")

# %%
chrome_opt=Options()
chrome_opt.add_argument("--incognito")
driver = webdriver.Chrome(service=s,options=chrome_opt)
capabilities = driver.capabilities
chrome_driver_version = capabilities['chrome']['chromedriverVersion']

# Print the ChromeDriver version
print("ChromeDriver version:", chrome_driver_version)
# Out:
# ChromeDriver version: 114.0.5735.90 (386bc09e8f4f2e025eddae123f36f6263096ae49-refs/branch-heads/5735@{#1052})

# %%
class postgres_conn:
    def getConn(self):
        try:
            connection = psycopg2.connect(user='postgres',
                                          password='postgres_007',
                                          host="1.pgsql.db.1digitalstack.com",
                                          port='5432',
                                          database='postgres')

            cursor = connection.cursor()
            # Print PostgreSQL Connection properties
            print(connection.get_dsn_parameters(), "\n")

            # Print PostgreSQL version
            return cursor, connection

        except (Exception, psycopg2.Error) as error:
            print("Error while connecting to PostgreSQL", error)
            return error, error
    def getConn2(self):
        try:
            connection = psycopg2.connect(user='postgres',
                                          password='reporting_007',
                                          host="2.pgsql.db.1digitalstack.com",
                                          port='5432',
                                          database='postgres')

            cursor = connection.cursor()
            # Print PostgreSQL Connection properties
            print(connection.get_dsn_parameters(), "\n")

            # Print PostgreSQL version
            return cursor, connection

        except (Exception, psycopg2.Error) as error:
            print("Error while connecting to PostgreSQL", error)
            return error, error


    def close_connection(self, cursor, connection):
        # closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
            
pg = postgres_conn()
conn = pg.getConn()
conn2 = pg.getConn2()
# Out:
# {'user': 'postgres', 'channel_binding': 'prefer', 'dbname': 'postgres', 'host': '1.pgsql.db.1digitalstack.com', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}
#
# {'user': 'postgres', 'channel_binding': 'prefer', 'dbname': 'postgres', 'host': '2.pgsql.db.1digitalstack.com', 'port': '5432', 'options': '', 'sslmode': 'prefer', 'sslcompression': '0', 'sslsni': '1', 'ssl_min_protocol_version': 'TLSv1.2', 'gssencmode': 'disable', 'krbsrvname': 'postgres', 'target_session_attrs': 'any'}

# %%
job_id=input("Enter keystone ids with comma.").split(",")
days=input(" Enter no of days for which data needs brand mapping.\n")
job_id.append("")
tuple(job_id)
# Out:
# Enter keystone ids with comma.64ccf0866364abab2c73bc8e
#  Enter no of days for which data needs brand mapping.
# 2
# ('64ccf0866364abab2c73bc8e', '')

# %%
query = f"""
select brand,title,sku,job_name,channel_id
from ready.serp_details smd join ready.serp_mongo_details m on m.serp_mongo_id=smd.serp_mongo_id
where smd.crawl_date > now() - interval '{days} day' and keystone_job_id in {tuple(job_id)}
"""
serp_details = pd.read_sql_query(query, conn[1])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_153656\2162843895.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   serp_details = pd.read_sql_query(query, conn[1])

# %%
serp_details
# Out:
#             brand                                              title  \
# 0              HP  HP AMD Ryzen 5 5500u | Win 11 Pro, Notebook wi...
# 1            KFA2  KFA2 GeForce RTX 4060 TI EX 1-Click OC (46ISL8...
# 2            ASUS          ASUS PH-RX550-4G-EVO (AMD, graphics card)
# 3            KFA2  KFA2 GeForce RTX 4070 2X 1-Click OC (47NOM7MD8...
# 4            ASUS  ASUS CERBERUS-GTX1050TI-A4G (NVIDIA, graphics ...
# ...           ...                                                ...
# 1195  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 1196  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 1197  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 1198  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 1199  SYSTEMTREFF  SYSTEMTREFF Pro Gaming Intel Core i7-12700KF, ...
#
#             sku                        job_name  channel_id
# 0     108089763  Mediamarket r.no.563 Serp_job           58
# 1       2890190  Mediamarket r.no.563 Serp_job           58
# 2      99429249  Mediamarket r.no.563 Serp_job           58
# 3       2890191  Mediamarket r.no.563 Serp_job           58
# 4      94003009  Mediamarket r.no.563 Serp_job           58
# ...         ...                             ...         ...
# 1195  109793811  Mediamarket r.no.563 Serp_job           58
# 1196  109793766  Mediamarket r.no.563 Serp_job           58
# 1197  109793825  Mediamarket r.no.563 Serp_job           58
# 1198  109793750  Mediamarket r.no.563 Serp_job           58
# 1199  107987524  Mediamarket r.no.563 Serp_job           58
#
# [1200 rows x 5 columns]

# %%
rawdf1=serp_details.drop_duplicates('sku')

df_ASIN = rawdf1[["sku"]]
df_ASIN.dropna(inplace=True)
df_ASIN.drop_duplicates(inplace=True)
asinlist = list(df_ASIN['sku'])
len(asinlist)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_153656\2610474507.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ASIN.dropna(inplace=True)
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_153656\2610474507.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ASIN.drop_duplicates(inplace=True)
# 749

# %%
query_2 = f""" 
Select channel_sku_id,country_code, brand_name, categories,category_id
from entity.product_master
where channel_sku_id in {tuple(asinlist)} 
"""

pm_data = pd.read_sql_query(query_2, conn[1])
pm_data
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_153656\3517360684.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pm_data = pd.read_sql_query(query_2, conn[1])
#     channel_sku_id country_code brand_name  \
# 0        100002649           DE    CAPTIVA
# 1        100002653           DE    CAPTIVA
# 2        100002659           DE    CAPTIVA
# 3        100003157           DE   SCREENON
# 4        100003239           DE   SCREENON
# ..             ...          ...        ...
# 749       99876555           DE       ACER
# 750       99876713           DE         HP
# 751       99886327           DE     Nvidia
# 752       99886334           DE        MSI
# 753       99895116           DE     LENOVO
#
#                                             categories category_id
# 0                                                 None        None
# 1                                                 None        None
# 2                                                 None        None
# 3                                                 None        None
# 4                                                 None        None
# ..                                                 ...         ...
# 749                                               None        None
# 750                                               None        None
# 751  [' Computer & Büro', ' Komponenten', ' Grafikk...        None
# 752                                               None        None
# 753                                               None        None
#
# [754 rows x 5 columns]

# %%
mapped_df=pd.merge(rawdf1,pm_data, how='left', left_on=['sku'],right_on=['channel_sku_id'])
mapped_df
# Out:
#            brand                                              title  \
# 0             HP  HP AMD Ryzen 5 5500u | Win 11 Pro, Notebook wi...
# 1           KFA2  KFA2 GeForce RTX 4060 TI EX 1-Click OC (46ISL8...
# 2           ASUS          ASUS PH-RX550-4G-EVO (AMD, graphics card)
# 3           KFA2  KFA2 GeForce RTX 4070 2X 1-Click OC (47NOM7MD8...
# 4           ASUS  ASUS CERBERUS-GTX1050TI-A4G (NVIDIA, graphics ...
# ..           ...                                                ...
# 749  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 750  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 751  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 752  SYSTEMTREFF  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 753  SYSTEMTREFF  SYSTEMTREFF Pro Gaming Intel Core i7-12700KF, ...
#
#            sku                        job_name  channel_id channel_sku_id  \
# 0    108089763  Mediamarket r.no.563 Serp_job           58      108089763
# 1      2890190  Mediamarket r.no.563 Serp_job           58        2890190
# 2     99429249  Mediamarket r.no.563 Serp_job           58       99429249
# 3      2890191  Mediamarket r.no.563 Serp_job           58        2890191
# 4     94003009  Mediamarket r.no.563 Serp_job           58       94003009
# ..         ...                             ...         ...            ...
# 749  109793811  Mediamarket r.no.563 Serp_job           58      109793811
# 750  109793766  Mediamarket r.no.563 Serp_job           58      109793766
# 751  109793825  Mediamarket r.no.563 Serp_job           58      109793825
# 752  109793750  Mediamarket r.no.563 Serp_job           58      109793750
# 753  107987524  Mediamarket r.no.563 Serp_job           58      107987524
#
#     country_code   brand_name  \
# 0             DE           HP
# 1             DE         KFA2
# 2             DE   Amd Radeon
# 3             DE         KFA2
# 4             DE       Nvidia
# ..           ...          ...
# 749           DE  SYSTEMTREFF
# 750           DE  SYSTEMTREFF
# 751           DE  SYSTEMTREFF
# 752           DE  SYSTEMTREFF
# 753           DE  SYSTEMTREFF
#
#                                             categories category_id
# 0                                                 None        None
# 1                                                 None        None
# 2    [' Computer & Büro', ' Komponenten', ' Grafikk...        None
# 3                                                 None        None
# 4    [' Computer & Büro', ' Komponenten', ' Grafikk...        None
# ..                                                 ...         ...
# 749                                               None        None
# 750                                               None        None
# 751                                               None        None
# 752                                               None        None
# 753                                               None        None
#
# [754 rows x 10 columns]

# %%
df2=mapped_df[mapped_df['categories'].isnull()][['channel_id','sku','title','brand_name']]
df2
# Out:
#      channel_id        sku                                              title  \
# 0            58  108089763  HP AMD Ryzen 5 5500u | Win 11 Pro, Notebook wi...
# 1            58    2890190  KFA2 GeForce RTX 4060 TI EX 1-Click OC (46ISL8...
# 3            58    2890191  KFA2 GeForce RTX 4070 2X 1-Click OC (47NOM7MD8...
# 6            58   93671492  POWERCOLOR AXRX 6800XT 16GBD6-3DHR/OC (AMD, gr...
# 7            58   85344259  INTEL Pentium G6605 box processor with boxed c...
# ..          ...        ...                                                ...
# 749          58  109793811  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 750          58  109793766  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 751          58  109793825  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 752          58  109793750  SYSTEMTREFF High-End Gaming Intel Core i7-1270...
# 753          58  107987524  SYSTEMTREFF Pro Gaming Intel Core i7-12700KF, ...
#
#       brand_name
# 0             HP
# 1           KFA2
# 3           KFA2
# 6     POWERCOLOR
# 7          INTEL
# ..           ...
# 749  SYSTEMTREFF
# 750  SYSTEMTREFF
# 751  SYSTEMTREFF
# 752  SYSTEMTREFF
# 753  SYSTEMTREFF
#
# [705 rows x 4 columns]

# %%
df=pd.DataFrame(columns=['channel_sku_id','categories','seller_info','first_image'])
df
# Out:
# Empty DataFrame
# Columns: [channel_sku_id, categories, seller_info, first_image]
# Index: []
