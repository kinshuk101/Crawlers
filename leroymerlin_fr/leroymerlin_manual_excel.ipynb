# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
from lxml import etree
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
import selenium.webdriver.support.expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from tqdm.notebook import tqdm
import time
import psycopg2
import json
import re
from selenium.webdriver.chrome.options import Options

# %% [raw]
# website is not scrapable due to blockage only node

# %%
df=pd.read_excel("leroymerlin_test.xlsx")

# %%
df
# Out:
#                            _id freedelivery  product_id  \
# 0     64d05ff8d42f1a4514c85fb3          NaN         NaN
# 1     64d05ff8d42f1a4514c85fb4          NaN         NaN
# 2     64d05ff8d42f1a4514c85fb5         True         NaN
# 3     64d05ff8d42f1a4514c85fb6         True         NaN
# 4     64d05ff8d42f1a4514c85fb7         True         NaN
# ...                        ...          ...         ...
# 6953  64d0664ad42f1a4514c8878e          NaN         NaN
# 6954  64d0664ad42f1a4514c8878f          NaN         NaN
# 6955  64d0664ad42f1a4514c88790         True         NaN
# 6956  64d0664ad42f1a4514c88791         True         NaN
# 6957  64d0664ad42f1a4514c88792         True         NaN
#
#                                             product_url  \
# 0     https://www.leroymerlin.fr/produits/terrasse-j...
# 1     https://www.leroymerlin.fr/produits/terrasse-j...
# 2     https://www.leroymerlin.fr/produits/terrasse-j...
# 3     https://www.leroymerlin.fr/produits/terrasse-j...
# ...

# %%
df.dropna(subset='sku',inplace=True)
df.drop_duplicates(subset='sku',inplace=True)
df.dropna(subset='product_url',inplace=True)
df.drop_duplicates(subset='product_url',inplace=True)
df.reset_index(drop=True, inplace=True)
df['categories']=''
df.shape
# Out:
# (929, 27)

# %%
for i in tqdm(range(len(df1))):
    split=df["product_url"][i].split('/')
    df['categories'][i]=split[4:-1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 for i in tqdm(range(len(df1))):
#       2     split=df1["product_url"][i].split('/')
#       3     df1['categories'][i]=split[4:-1]
#
# NameError: name 'df1' is not defined
