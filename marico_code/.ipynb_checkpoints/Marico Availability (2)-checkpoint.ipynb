# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import requests
from selenium.webdriver.support.ui import WebDriverWait
import selenium.webdriver.support.expected_conditions as EC
from tqdm.notebook import tqdm
import time
# from scrapy import Selector


#import spacy
#from spacy import displacy
#from collections import Counter
#import en_core_web_sm
#nlp = en_core_web_sm.load()

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver = webdriver.Chrome(executable_path = r'chromedriver.exe',chrome_options = chrome_options)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_150332\1496906039.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = r'chromedriver.exe',chrome_options = chrome_options)
# C:\Users\Administrator\AppData\Local\Temp\2\ipykernel_150332\1496906039.py:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path = r'chromedriver.exe',chrome_options = chrome_options)

# %%
df1 = pd.read_excel(r"for upd ae.xlsx",engine = 'openpyxl')

# %%
df_ASIN = df1["sku"].copy()
df_ASIN.drop_duplicates(inplace=True)
df_ASIN.dropna(inplace = True)
asinList = list(df_ASIN)
len(asinList)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sku'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df_ASIN = df1["sku"].copy()
#       2 df_ASIN.drop_duplicates(inplace=True)
#       3 df_ASIN.dropna(inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'sku'

# %%
timeout = 10
locator = "imgTagWrapperId"
productDetails = {}
lastIdx = 0
for val in tqdm(range(len(asinList))):
    try:
   
        i = asinList[val]
        print("i",i)
        productDetails[i] = {}
        lastIdx = val
        link = "https:amazon.ae/dp/" + i
        print(link)
        driver.get(link)
        WebDriverWait(driver, timeout).until(EC.visibility_of_element_located((By.ID, locator)))
        try:
            TitleVal = driver.find_element(By.ID,'title')
            productDetails[i]['Title'] = TitleVal.text
            print(TitleVal.text)
        
        except:
            productDetails[i]['Title'] = "Not Found"
            print("Product Title not found")


        try:
            BrandVal = driver.find_element(By.ID,'bylineInfo')
            productDetails[i]['Brand_Subscript'] = BrandVal.text
            print(BrandVal.text)

        except:
            productDetails[i]['Brand_Subscript'] = "Not Found"
            print("Brand from subscript not found")
            
        try:
            Availval = driver.find_element(By.ID,'availability')
            productDetails[i]['Availability'] = Availval.text
            print(Availval.text)    

        except:
            productDetails[i]['Availability'] = "Not Found"
            print("Brand from subscript not found")    
           
        try:
            Availval = driver.find_element(By.ID,'merchant-info')
            productDetails[i]['Seller'] = Availval.text
            print(Availval.text)    

        except:
            productDetails[i]['Seller'] = "Not Found"
            print("Brand from subscript not found")    
        
        try:
            Table = driver.find_element(By.ID,'productOverview_feature_div')
            df = pd.read_html(Table.get_attribute("innerHTML"))[0]
            productDetails[i].update(dict(zip(df.iloc[:,0],df.iloc[:,1])))
            print("Product Details",productDetails[i])
        except:
            print("No Product Overview Table Found")
            # productDetails[i] = {}
        try:
            productFeatures = driver.find_element(By.ID,'detailBullets_feature_div')
            features = productFeatures.find_elements(By.TAG_NAME,'li')
            featureDetails = {}
            for j in features:
                featurePair = j.text.split(":")
                try:
                    featureDetails[featurePair[0].strip()] = featurePair[1]
                except:
                    pass
            print("featureDetails",featureDetails)
            productDetails[i].update(featureDetails)
            print("Product Details",productDetails[i])
        except:
            print("featureDetails not found")

        try:
            Table2 = driver.find_element(By.ID,'productDetails_techSpec_section_1')
            technicalDetails = {}
            headers = Table2.find_elements(By.TAG_NAME,'th')
            vals = Table2.find_elements(By.TAG_NAME,'td')
            for k in range(len(headers)):
                try:
                    technicalDetails[headers[k].text.strip()] = vals[k].text
                except:
                    pass
            print("technicalDetails",technicalDetails)
            productDetails[i].update(technicalDetails)
            print(productDetails[i])
        except:
            pass
        try:
            Table3 = driver.find_element(By.ID,'productDetails_detailBullets_sections1')
            dfaDetails = {}
            headers = Table3.find_elements(By.TAG_NAME,'th')
            vals = Table3.find_elements(By.TAG_NAME,'td')
            for k in range(len(headers)):
                try:
                    dfaDetails[headers[k].text.strip()] = vals[k].text
                except:
                    pass
            print("dfaDetails",dfaDetails)
            productDetails[i].update(dfaDetails)
            print(productDetails[i])
        except:
            pass
        try:
            
            SRank = driver.find_element(By.ID,'SalesRank')
            BestSellerRankStr = SRank.text.replace("Amazon Bestsellers Rank: ","")
            BestSellerRankDetails = {'Best Sellers Rank': BestSellerRankStr}
            productDetails[i].update(BestSellerRankDetails)
            print(productDetails[i])
        except:
            pass
        
    except:
        pass

# %%
df_productDetails = pd.DataFrame.from_dict(productDetails,orient='index')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_productDetails = pd.DataFrame.from_dict(productDetails,orient='index')
#
# NameError: name 'productDetails' is not defined

# %%
df_productDetails['Brand_Subscript'] = df_productDetails['Brand_Subscript'].str.replace('^Brand:\s','').str.replace('\sStore$','').str.replace('^Visit\sthe\s','')
# Out:
# C:\Users\prati\AppData\Local\Temp/ipykernel_18212/1461516328.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_productDetails['Brand_Subscript'] = df_productDetails['Brand_Subscript'].str.replace('^Brand:\s','').str.replace('\sStore$','').str.replace('^Visit\sthe\s','')

# %%
df_productDetails
# Out:
#                                                         Title  \
# B000052XZZ  Neutrogena T/Gel Therapeutic Shampoo Original ...
# B000058DRJ  The First Years Bottle And Teat Brush, Assorte...
# B00005NAOD  Eucerin Q10 Anti-Wrinkle Face Cream, Unscented...
# B0005Z7PTO                   Newman'S Own Medium Salsa, 453 G
# B00066N8Z2  Wind Song Dusting Powder for Women by Prince M...
# B000684HJQ  Sesderma | C-Vit Eye Contour Cream | Vitamin C...
# B0009OAHEQ                  JOOP! for Men, 125 ml - EDT Spray
# B0009QZXRU  Africa's Best Herbal Intensive Dual Conditioni...
# B000ARPVIY      Bona Hardwood Floor Cleaner Refill, 128 Fl Oz
# B000AXSG26          Peppermint Syrup 750ml Pet Plastic Bottle
# B000BGPLAW  Africa'S Best Organics Organic Conditioning Re...
#
#                Brand_Subscript                            Availability  \
# B000052XZZ          Neutrogena                                In Stock
# B000058DRJ     The First Years                                In Stock
# B00005NAOD             Eucerin
# B0005Z7PTO        Newman'S Own                                In Stock
# B00066N8Z2  Prince Matchabelli                                In Stock
# B000684HJQ            Sesderma        Usually ships within 4 to 5 days
# B0009OAHEQ               Joop!                                In Stock
# B0009QZXRU       Africa's Best  Only 1 left in stock (more on the way)
# B000ARPVIY                Bona       Only 2 left in stock - order soon
# B000AXSG26              Torani                                In Stock
# B000BGPLAW       Africa's Best                                In Stock
#
#                Seller               Brand Item form              Hair type  \
# B000052XZZ  Not Found          Neutrogena    Liquid               Dandruff
# B000058DRJ  Not Found     The First Years       NaN                    NaN
# B00005NAOD                        Eucerin     Cream                    NaN
# B0005Z7PTO  Not Found        Newman'S Own       NaN                    NaN
# B00066N8Z2  Not Found  Prince Matchabelli    Powder                    NaN
# B000684HJQ  Not Found            Sesderma     Cream                    NaN
# B0009OAHEQ  Not Found               Joop!    Liquid                    NaN
# B0009QZXRU  Not Found       Africa's Best     Cream                 Normal
# B000ARPVIY  Not Found                Bona    Liquid                    NaN
# B000AXSG26  Not Found              Torani       NaN                    NaN
# B000BGPLAW  Not Found       Africa's Best     Cream  relaxed-textured-hair
#
#                      Scent Age range (description)  \
# B000052XZZ       Unscented                   Adult
# B000058DRJ             NaN                     NaN
# B00005NAOD  Fragrance free                     NaN
# B0005Z7PTO             NaN                     NaN
# B00066N8Z2             NaN                   Adult
# B000684HJQ            Rose                     NaN
# B0009OAHEQ        Oriental                     NaN
# B0009QZXRU             NaN                     NaN
# B000ARPVIY      Unscented                      NaN
# B000AXSG26             NaN                     NaN
# B000BGPLAW             NaN                     NaN
#
#            Is Discontinued By Manufacturer  ... Material features  \
# B000052XZZ                             Yes  ...               NaN
# B000058DRJ                             NaN  ...               NaN
# B00005NAOD                              No  ...               NaN
# B0005Z7PTO                             NaN  ...               NaN
# B00066N8Z2                              No  ...               NaN
# B000684HJQ                              No  ...               NaN
# B0009OAHEQ                              No  ...               NaN
# B0009QZXRU                              No  ...               NaN
# B000ARPVIY                             NaN  ...           Natural
# B000AXSG26                             NaN  ...               NaN
# B000BGPLAW                              No  ...               NaN
#
#            Specific uses Is mould resistant Is assembly required  \
# B000052XZZ           NaN                NaN                  NaN
# B000058DRJ           NaN                NaN                  NaN
# B00005NAOD           NaN                NaN                  NaN
# B0005Z7PTO           NaN                NaN                  NaN
# B00066N8Z2           NaN                NaN                  NaN
# B000684HJQ           NaN                NaN                  NaN
# B0009OAHEQ           NaN                NaN                  NaN
# B0009QZXRU           NaN                NaN                  NaN
# B000ARPVIY         Floor      Chlorine Free                   No
# B000AXSG26           NaN                NaN                  NaN
# B000BGPLAW           NaN                NaN                  NaN
#
#            Included components Package information           Volume Format  \
# B000052XZZ                 NaN                 NaN              NaN    NaN
# B000058DRJ                 NaN                 NaN              NaN    NaN
# B00005NAOD                 NaN                 NaN              NaN    NaN
# B0005Z7PTO                 NaN                 NaN              NaN    NaN
# B00066N8Z2                 NaN                 NaN              NaN    NaN
# B000684HJQ                 NaN                 NaN              NaN    NaN
# B0009OAHEQ                 NaN                 NaN              NaN    NaN
# B0009QZXRU                 NaN                 NaN              NaN    NaN
# B000ARPVIY     Cleaning Refill                 NaN              NaN    NaN
# B000AXSG26                 NaN              Bottle  750 Milliliters    तरल
# B000BGPLAW                 NaN                 NaN              NaN    NaN
#
#            Package Information Product benefits
# B000052XZZ                 NaN              NaN
# B000058DRJ                 NaN              NaN
# B00005NAOD                 NaN              NaN
# B0005Z7PTO                 NaN              NaN
# B00066N8Z2                 NaN              NaN
# B000684HJQ                 NaN              NaN
# B0009OAHEQ                 NaN              NaN
# B0009QZXRU                 NaN              NaN
# B000ARPVIY                 NaN              NaN
# B000AXSG26              Bottle              NaN
# B000BGPLAW                 NaN    Anti-Breakage
#
# [11 rows x 51 columns]

# %%
df_productDetails.to_excel(r"brand NEW.xlsx")
